# %% [markdown]
# Step 1: Import necessary libraries

# %%
import numpy as np # linear algebra
import gc
import matplotlib.pyplot as plt
import cv2 as cv
import os
import seaborn as sns
from keras.utils import to_categorical
from keras.models import Sequential
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Step 2: Analyze and Visualize data

# %%
root_path = '/kaggle/input/pokemon-generation-one/dataset/dataset'
classes = os.listdir(root_path)
count=0
count_dict = {}
print(f'Total number of pokemons: {len(classes)}')
for pokemon in classes:
    dir_path = os.path.join(root_path, pokemon)
    count+=len(os.listdir(dir_path))
    count_dict[pokemon] = len(os.listdir(dir_path))
print(f'Total number of images: {count}')
fig = plt.figure(figsize = (25, 5))
sns.lineplot(x = list(count_dict.keys()), y = list(count_dict.values())).set_title('Number of images for each pokemon')
plt.xticks(rotation = 90)
plt.margins(x=0)
plt.show()
# Out:
# Total number of pokemons: 149
# Total number of images: 10693

# %%
# sorted the list of pokemons with respect to number of their appearances in the datasett
sorted_list =  sorted(count_dict.items(), key=lambda item: item[1], reverse=True)
sorted_list
# Out:
# [('Mewtwo', 307),
#  ('Pikachu', 298),
#  ('Charmander', 296),
#  ('Bulbasaur', 289),
#  ('Squirtle', 280),
#  ('Psyduck', 159),
#  ('Spearow', 130),
#  ('Fearow', 124),
#  ('Dratini', 109),
#  ('Aerodactyl', 97),
#  ('Rapidash', 83),
#  ('Shellder', 81),
#  ('Ninetales', 74),
#  ('Pidgey', 74),
#  ('Mankey', 72),
#  ('Machamp', 72),
#  ('Sandslash', 71),
#  ('Raichu', 71),
#  ('Lapras', 71),
#  ('Muk', 71),
#  ('Meowth', 70),
#  ('Primeape', 70),
#  ('Marowak', 70),
#  ('Exeggutor', 70),
#  ('Raticate', 70),
#  ('Kingler', 69),
#  ('Rhyhorn', 69),
#  ('Growlithe', 69),
#  ('Snorlax', 69),
#  ('Scyther', 68),
#  ('Vaporeon', 68),
#  ('Nidoking', 68),
#  ('Vulpix', 68),
#  ('Gyarados', 68),
#  ('Dewgong', 67),
#  ('Electrode', 67),
#  ('Wigglytuff', 67),
#  ('Lickitung', 67),
#  ('Mew', 67),
#  ('Tauros', 67),
#  ('Kakuna', 67),
#  ('Vileplume', 67),
#  ('Golbat', 67),
#  ('Rattata', 67),
#  ('Seadra', 67),
#  ('Pidgeot', 66),
#  ('Butterfree', 66),
#  ('Venusaur', 66),
#  ('Ponyta', 66),
#  ('Venomoth', 66),
#  ('Nidoqueen', 66),
#  ('Oddish', 66),
#  ('Sandshrew', 66),
#  ('Kabutops', 66),
#  ('Metapod', 65),
#  ('Voltorb', 65),
#  ('Dragonair', 65),
#  ('Poliwag', 65),
#  ('Hitmonlee', 65),
#  ('Charmeleon', 65),
#  ('Jigglypuff', 65),
#  ('Dodrio', 65),
#  ('Koffing', 65),
#  ('Seaking', 65),
#  ('Jolteon', 64),
#  ('Onix', 64),
#  ('Grimer', 64),
#  ('Golem', 64),
#  ('Poliwhirl', 64),
#  ('Dugtrio', 64),
#  ('Krabby', 64),
#  ('Farfetchd', 64),
#  ('Nidorino', 63),
#  ('Poliwrath', 63),
#  ('Hypno', 63),
#  ('Weezing', 63),
#  ('Haunter', 63),
#  ('Tangela', 63),
#  ('Arbok', 63),
#  ('Kangaskhan', 63),
#  ('Slowbro', 63),
#  ('Horsea', 63),
#  ('Pinsir', 63),
#  ('Pidgeotto', 63),
#  ('Dragonite', 62),
#  ('Blastoise', 62),
#  ('Moltres', 62),
#  ('Wartortle', 61),
#  ('Arcanine', 61),
#  ('Hitmonchan', 61),
#  ('Seel', 61),
#  ('Golduck', 61),
#  ('Kadabra', 61),
#  ('Drowzee', 60),
#  ('Cloyster', 60),
#  ('Magnemite', 60),
#  ('Gengar', 60),
#  ('Slowpoke', 60),
#  ('Clefairy', 60),
#  ('Zapdos', 60),
#  ('Staryu', 60),
#  ('Flareon', 59),
#  ('Weedle', 59),
#  ('Starmie', 59),
#  ('MrMime', 59),
#  ('Magneton', 59),
#  ('Rhydon', 59),
#  ('Cubone', 59),
#  ('Nidorina', 59),
#  ('Jynx', 59),
#  ('Magmar', 59),
#  ('Magikarp', 59),
#  ('Graveler', 58),
#  ('Gloom', 58),
#  ('Goldeen', 58),
#  ('Chansey', 58),
#  ('Omastar', 58),
#  ('Exeggcute', 57),
#  ('Venonat', 57),
#  ('Tentacruel', 57),
#  ('Tentacool', 57),
#  ('Persian', 57),
#  ('Kabuto', 56),
#  ('Geodude', 56),
#  ('Articuno', 56),
#  ('Paras', 55),
#  ('Omanyte', 55),
#  ('Bellsprout', 55),
#  ('Victreebel', 55),
#  ('Porygon', 55),
#  ('Electabuzz', 54),
#  ('Machop', 53),
#  ('Parasect', 53),
#  ('Beedrill', 53),
#  ('Ivysaur', 53),
#  ('Ekans', 52),
#  ('Charizard', 52),
#  ('Weepinbell', 51),
#  ('Machoke', 51),
#  ('Diglett', 51),
#  ('Caterpie', 50),
#  ('Gastly', 50),
#  ('Zubat', 49),
#  ('Clefable', 49),
#  ('Ditto', 49),
#  ('Alakazam', 49),
#  ('Doduo', 48),
#  ('Abra', 42),
#  ('Eevee', 41)]

# %%
# pick the 50 most frequently appears
chosen_pokemon = sorted_list[0:50]
chosen_pokemon
# Out:
# [('Mewtwo', 307),
#  ('Pikachu', 298),
#  ('Charmander', 296),
#  ('Bulbasaur', 289),
#  ('Squirtle', 280),
#  ('Psyduck', 159),
#  ('Spearow', 130),
#  ('Fearow', 124),
#  ('Dratini', 109),
#  ('Aerodactyl', 97),
#  ('Rapidash', 83),
#  ('Shellder', 81),
#  ('Ninetales', 74),
#  ('Pidgey', 74),
#  ('Mankey', 72),
#  ('Machamp', 72),
#  ('Sandslash', 71),
#  ('Raichu', 71),
#  ('Lapras', 71),
#  ('Muk', 71),
#  ('Meowth', 70),
#  ('Primeape', 70),
#  ('Marowak', 70),
#  ('Exeggutor', 70),
#  ('Raticate', 70),
#  ('Kingler', 69),
#  ('Rhyhorn', 69),
#  ('Growlithe', 69),
#  ('Snorlax', 69),
#  ('Scyther', 68),
#  ('Vaporeon', 68),
#  ('Nidoking', 68),
#  ('Vulpix', 68),
#  ('Gyarados', 68),
#  ('Dewgong', 67),
#  ('Electrode', 67),
#  ('Wigglytuff', 67),
#  ('Lickitung', 67),
#  ('Mew', 67),
#  ('Tauros', 67),
#  ('Kakuna', 67),
#  ('Vileplume', 67),
#  ('Golbat', 67),
#  ('Rattata', 67),
#  ('Seadra', 67),
#  ('Pidgeot', 66),
#  ('Butterfree', 66),
#  ('Venusaur', 66),
#  ('Ponyta', 66),
#  ('Venomoth', 66)]

# %% [markdown]
# Step 3: Generate data and preprocessing

# %%
#functions to augment more images
def generate_extra_two(img):
    return img[0:96, 0:96,:], img[4:100, 4:100, :]
def generate_extra_three(img):
    return generate_extra_two(img)[0], generate_extra_two(img)[1], img[2:98,2:98,:]

# %%
#generate data and labels
X = []
y= []
poke_label_dict = {}
i=0
for pokemon in chosen_pokemon:
    name = pokemon[0]
    poke_label_dict[i] = name
    print(name+ ': ' + str(i))
    dir_path = os.path.join(root_path, name)
    j=0
    if pokemon[1] < 70:
        for filename in os.listdir(dir_path):   
            try:
                file_path = os.path.join(dir_path, filename)
                img = cv.imread(file_path, 1)
                img = cv.resize(img, (100, 100))
                extra = generate_extra_three(img)
                for e in range(3):
                    X.append(extra[e])
                    y.append(i)
                gc.collect()
            except:
                j+=1
                print(str(j)+ " Broken file(s)")

    elif pokemon[1] < 100:
        for filename in os.listdir(dir_path):   
            try:
                file_path = os.path.join(dir_path, filename)
                img = cv.imread(file_path, 1)
                img = cv.resize(img, (100, 100))
                extra = generate_extra_two(img)
                for e in range(2):
                    X.append(extra[e])
                    y.append(i)
                gc.collect()
            except:
                j+=1
                print(str(j)+ " Broken file(s)")    
    else:
        for filename in os.listdir(dir_path):   
            try:
                file_path = os.path.join(dir_path, filename)
                img = cv.imread(file_path, 1)
                img = cv.resize(img, (96, 96))
                X.append(img)
                y.append(i)
                gc.collect()
            except:
                j+=1
                print(str(j)+ " Broken file(s)")
    i+=1
# Out:
# Mewtwo: 0
# 1 Broken file(s)
# Pikachu: 1
# Charmander: 2
# Bulbasaur: 3
# Squirtle: 4
# Psyduck: 5
# Spearow: 6
# Fearow: 7
# 1 Broken file(s)
# 2 Broken file(s)
# Dratini: 8
# Aerodactyl: 9
# Rapidash: 10
# Shellder: 11
# Ninetales: 12
# Pidgey: 13
# Mankey: 14
# Machamp: 15
# 1 Broken file(s)
# Sandslash: 16
# Raichu: 17
# Lapras: 18
# Muk: 19
# Meowth: 20
# Primeape: 21
# Marowak: 22
# Exeggutor: 23
# 1 Broken file(s)
# 2 Broken file(s)
# Raticate: 24
# Kingler: 25
# 1 Broken file(s)
# Rhyhorn: 26
# Growlithe: 27
# 1 Broken file(s)
# Snorlax: 28
# Scyther: 29
# 1 Broken file(s)
# Vaporeon: 30
# Nidoking: 31
# Vulpix: 32
# Gyarados: 33
# 1 Broken file(s)
# Dewgong: 34
# 1 Broken file(s)
# Electrode: 35
# Wigglytuff: 36
# Lickitung: 37
# Mew: 38
# Tauros: 39
# Kakuna: 40
# Vileplume: 41
# Golbat: 42
# Rattata: 43
# Seadra: 44
# Pidgeot: 45
# Butterfree: 46
# Venusaur: 47
# Ponyta: 48
# Venomoth: 49
# 1 Broken file(s)

# %%
#convert X to 4-dimensional tensor
X = np.array(X).reshape(-1, 96, 96, 3)
#normalize X
X = X/255.0
#convert y to one-hot-encoded form
y = to_categorical(np.array(y))

# %%
#check shape of X and Y
X.shape, y.shape
# Out:
# ((9388, 96, 96, 3), (9388, 50))

# %%
#check if X has been normailized
X.max(),X.min()
# Out:
# (1.0, 0.0)

# %%
#split data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, random_state=500,test_size=0.2)

# %%
#check shape of training and test data
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7510, 96, 96, 3), (1878, 96, 96, 3), (7510, 50), (1878, 50))

# %%
#split data into training and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, shuffle=True, random_state=500,test_size=0.4)

# %%
#check shape of training and validation data
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((4506, 96, 96, 3), (3004, 96, 96, 3), (4506, 50), (3004, 50))

# %%
#check length of label dictionary
len(poke_label_dict)
# Out:
# 50

# %%
#visulaize some example in training set and some example in validation set
import random
def vis_ex(X,y):
    plt.figure(1,figsize=(15, 10))
    for i in range(1,9):
        c = random.randint(0, 2000)
        img = X[c]
        plt.subplot(5,8,i)
        plt.imshow(img)
        plt.title(poke_label_dict[np.argmax(y[c])])

# %%
vis_ex(X_train, y_train)

# %%
vis_ex(X_val, y_val)

# %% [markdown]
# Step 4 : Build a CNN-model based on Alex

# %%
model= Sequential()
#Phase 1: 2 Conv-> Pooling block
model.add(layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), 
                       padding='valid' , input_shape=(96,96,3),activation='relu'))
model.add(layers.BatchNormalization(axis=-1))
model.add(layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)))
model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', activation='relu'))
model.add(layers.BatchNormalization(axis=-1))
model.add(layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)))
#Phase 2: Convol Phase
model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(layers.BatchNormalization(axis=-1))
model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(layers.BatchNormalization(axis=-1))
model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(layers.BatchNormalization(axis=-1))
model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2))) #modified from pool(3,3) to fit the input
#Phase 3: Fully-connected Phase: #modify the second FC layer from original paper due to low number of training examples 
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=1024, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=y_train.shape[1], activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_23 (Conv2D)           (None, 22, 22, 96)        34944
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 22, 22, 96)        384
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 10, 96)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 10, 10, 256)       614656
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 4, 4, 384)         885120
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 4, 4, 384)         1536
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 4, 4, 384)         1327488
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 4, 4, 384)         1536
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 4, 4, 256)         884992
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               524800
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                25650
# =================================================================
# Total params: 5,358,898
# Trainable params: 5,353,074
# Non-trainable params: 5,824
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#create datagen during training and validation
train_datagen = ImageDataGenerator(horizontal_flip=True,
                                   rotation_range = 45, 
                                   width_shift_range = 0.15,  
                                   height_shift_range = 0.15)
test_datagen = ImageDataGenerator(horizontal_flip=True)
train_generator =  train_datagen.flow(X_train, y_train, batch_size=256, shuffle=True)
val_generator = test_datagen.flow(X_val, y_val, batch_size=256, shuffle=True)

# %%
history = model.fit_generator(train_generator, validation_data=val_generator, epochs=100, 
                              steps_per_epoch=len(train_generator),validation_steps= len(val_generator))
# Out:
# Epoch 1/10
# 18/18 [==============================] - 10s 535ms/step - loss: 0.4095 - accuracy: 0.8824 - val_loss: 1.6218 - val_accuracy: 0.7107
# Epoch 2/10
# 18/18 [==============================] - 9s 523ms/step - loss: 0.3744 - accuracy: 0.8859 - val_loss: 1.2128 - val_accuracy: 0.6794
# Epoch 3/10
# 18/18 [==============================] - 10s 536ms/step - loss: 0.3266 - accuracy: 0.9032 - val_loss: 2.0159 - val_accuracy: 0.6751
# Epoch 4/10
# 18/18 [==============================] - 9s 522ms/step - loss: 0.3201 - accuracy: 0.9055 - val_loss: 1.3869 - val_accuracy: 0.7051
# Epoch 5/10
# 18/18 [==============================] - 10s 536ms/step - loss: 0.3323 - accuracy: 0.9030 - val_loss: 1.3594 - val_accuracy: 0.7354
# Epoch 6/10
# 18/18 [==============================] - 10s 570ms/step - loss: 0.2927 - accuracy: 0.9079 - val_loss: 1.4898 - val_accuracy: 0.7557
# Epoch 7/10
# 18/18 [==============================] - 9s 524ms/step - loss: 0.3107 - accuracy: 0.9075 - val_loss: 0.7452 - val_accuracy: 0.7423
# Epoch 8/10
# 18/18 [==============================] - 9s 523ms/step - loss: 0.3014 - accuracy: 0.9139 - val_loss: 0.8675 - val_accuracy: 0.7590
# Epoch 9/10
# 18/18 [==============================] - 9s 523ms/step - loss: 0.3088 - accuracy: 0.9117 - val_loss: 1.4924 - val_accuracy: 0.7304
# Epoch 10/10
# 18/18 [==============================] - 10s 533ms/step - loss: 0.2956 - accuracy: 0.9172 - val_loss: 1.9475 - val_accuracy: 0.7021

# %% [markdown]
# Step 4: Evaluation

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.45      0.52        64
#            1       0.95      0.60      0.74        58
#            2       0.69      0.80      0.74        71
#            3       0.75      0.73      0.74        59
#            4       0.58      0.80      0.67        60
#            5       0.69      0.81      0.75        31
#            6       0.52      0.68      0.59        19
#            7       0.38      0.54      0.44        28
#            8       0.58      0.55      0.56        20
#            9       0.97      0.74      0.84        42
#           10       0.73      0.37      0.49        30
#           11       0.90      0.93      0.92        30
#           12       0.82      0.56      0.67        25
#           13       0.32      0.31      0.32        32
#           14       0.90      0.27      0.42        33
#           15       0.90      0.56      0.69        34
#           16       0.80      0.55      0.65        22
#           17       0.63      0.65      0.64        26
#           18       0.57      0.84      0.68        32
#           19       0.57      0.74      0.64        23
#           20       0.93      0.56      0.70        25
#           21       0.58      0.64      0.61        22
#           22       0.58      0.54      0.56        39
#           23       0.48      0.69      0.56        29
#           24       0.93      0.41      0.57        32
#           25       0.73      0.92      0.81        36
#           26       0.68      0.68      0.68        28
#           27       0.87      0.83      0.85        41
#           28       1.00      0.77      0.87        47
#           29       0.62      0.83      0.71        41
#           30       0.91      0.75      0.82        55
#           31       0.85      0.79      0.82        43
#           32       0.76      0.74      0.75        39
#           33       0.77      0.77      0.77        43
#           34       0.77      0.66      0.71        35
#           35       0.79      0.93      0.85        41
#           36       0.70      0.87      0.78        38
#           37       0.77      0.85      0.81        47
#           38       0.49      0.61      0.54        33
#           39       0.97      0.74      0.84        39
#           40       0.83      0.95      0.88        40
#           41       0.81      0.94      0.87        36
#           42       0.81      0.97      0.89        36
#           43       0.91      0.77      0.83        39
#           44       0.73      0.59      0.65        41
#           45       0.60      0.75      0.67        44
#           46       0.97      0.83      0.90        36
#           47       0.48      0.95      0.64        38
#           48       0.90      0.67      0.77        42
#           49       0.82      0.91      0.86        34
#
#     accuracy                           0.72      1878
#    macro avg       0.74      0.71      0.71      1878
# weighted avg       0.75      0.72      0.72      1878

# %%
#plot some predictions:
def vis_pred(X):
    plt.figure(1,figsize=(15, 10))
    for i in range(1,9):
        c = random.randint(0, 1000)
        img = X[c]
        plt.subplot(5,8,i)
        plt.imshow(img)
        plt.title(poke_label_dict[np.argmax(model.predict(img.reshape(1,96,96,3)))])

# %%
vis_pred(X_test)

# %% [markdown]
# Step 7: Save  model

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_pkm.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_pkm.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
